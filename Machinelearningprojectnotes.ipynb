# %%
#DATA CLEANING

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
originaltrain=pd.read_csv('train.csv', index_col='Id')

# %%
originaltest=pd.read_csv('test.csv', index_col='Id')

# %%
totaldata=pd.concat([originaltrain, originaltest], axis=0)

# %%
originaltrain.shape
# Out:
# (1460, 80)

# %%
originaltest.shape
# Out:
# (1459, 79)

# %%
pd.options.display.max_columns = None
originaltrain.sample(80)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1421          60       RL         90.0    11700   Pave   NaN      Reg
# 1336          20       RL         80.0     9650   Pave   NaN      Reg
# 592           60       RL         97.0    13478   Pave   NaN      IR1
# 126          190       RM         60.0     6780   Pave   NaN      Reg
# 1199          20       RL         70.0     9100   Pave   NaN      Reg
# 590           40       RM         50.0     9100   Pave   NaN      Reg
# 1070          45       RL         60.0     9600   Pave   NaN      Reg
# 880           20       RL          NaN     7000   Pave   NaN      IR1
# 906           20       RL         80.0     9920   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1153          20       RL         90.0    14115   Pave   NaN      IR1
# 692           60       RL        104.0    21535   Pave   NaN      IR1
# ...

# %%
pd.set_option('display.max_rows', 90)
#originaltrain.dtypes

# %%
pd.set_option('display.max_rows', 90)
originaltrain[originaltrain.Condition1==originaltrain.Condition2]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
pd.set_option('display.max_rows', 90)
originaltrain[['BsmtFinType1','BsmtFinType2']].sample(50)
# Out:
#      BsmtFinType1 BsmtFinType2
# Id
# 48            GLQ          Unf
# 766           Unf          Unf
# 734           BLQ          Unf
# 90            GLQ          Unf
# 1083          Unf          Unf
# 342           Unf          Unf
# 125           Unf          Unf
# 238           BLQ          Unf
# 150           Unf          Unf
# 1268          Unf          Unf
# 871           Unf          Unf
# 94            Rec          Unf
# 976           GLQ          Unf
# 920           ALQ          BLQ
# 1142          ALQ          Unf
# 1360          GLQ          Unf
# 669           Rec          Unf
# 1377          Rec          Unf
# 901           ALQ          Unf
# 449           Unf          Unf
# 1097          Unf          Unf
# 1340          Rec          Unf
# 1423          GLQ          Unf
# 536           GLQ          Unf
# 3             GLQ          Unf
# 28            GLQ          Unf
# 809           ALQ          BLQ
# 1109          Unf          Unf
# 147           BLQ          Unf
# ...

# %%
originaltrain[originaltrain.Exterior1st==originaltrain.Exterior2nd]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
1245/1460
# Out:
# 0.8527397260273972

# %%
originaltrain.MasVnrType.value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
originaltrain[['YearBuilt','GarageYrBlt']].sample(40)
# Out:
#       YearBuilt  GarageYrBlt
# Id
# 242        1945          NaN
# 1384       1918       2007.0
# 1303       1994       1994.0
# 572        1959       1959.0
# 1326       1922          NaN
# 634        1954       1954.0
# 87         2005       2005.0
# 528        2008       2008.0
# 886        1999       1999.0
# 301        1953       1953.0
# 296        1984       1984.0
# 900        1961       1961.0
# 1134       1995       1995.0
# 877        1963       1963.0
# 141        1971          NaN
# 1177       1984       1984.0
# 163        2005       2005.0
# 984        2002       2002.0
# 965        2002       2002.0
# 1222       1968       1968.0
# 981        1961       1961.0
# 119        1990       1990.0
# 321        2006       2006.0
# 1190       1999       1999.0
# 433        1971       1971.0
# 514        1983       1983.0
# 575        1971       1971.0
# 848        1972       1972.0
# 1460       1965       1965.0
# 511        1951       1951.0
# 137        1967       1967.0
# ...

# %%
totaldata[totaldata['GarageQual']==totaldata['GarageCond']]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2912          20       RL         80.0    13384   Pave   NaN      Reg
# 2913         160       RM         21.0     1533   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
originaltrain[['GarageQual','GarageCond']].sample(40)
# Out:
#      GarageQual GarageCond
# Id
# 1373         TA         TA
# 359          TA         TA
# 1035         Fa         TA
# 1013         TA         TA
# 429          TA         TA
# 730          TA         TA
# 1187         Fa         Fa
# 1206         TA         TA
# 814          TA         TA
# 1407         TA         TA
# 503          Fa         Fa
# 781          TA         TA
# 880          TA         TA
# 812          TA         TA
# 999          TA         Fa
# 501          TA         TA
# 144          TA         TA
# 1349         TA         TA
# 907          TA         TA
# 288         NaN        NaN
# 442         NaN        NaN
# 327          TA         TA
# 169          TA         TA
# 405          TA         TA
# 145          TA         TA
# 160          TA         TA
# 982          TA         TA
# 1111         TA         TA
# 1072         TA         TA
# 269          Ex         Ex
# 675          TA         TA
# 869          TA         TA
# 297          TA         TA
# ...

# %%
originaltrain['LotFrontage'].isna().sum()
# Out:
# 259

# %%
pd.isnull(totaldata).sum(axis=0)
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         24
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
#Get rid of PoolQC, Fence, MiscFeature columns
#GarageQual and GarageCond replace NA with none

# %%
totaldata.shape
# Out:
# (2919, 80)
